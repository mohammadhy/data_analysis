# %% [markdown]
# ## Airplane Crash

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
org_data = pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908_DV_03032020.csv')

# %%
org_data.head()
# Out:
#          DATE   TIME                            LOCATION  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  09/07/1909    NaN             Juvisy-sur-Orge, France
# 2  07/12/1912  06:30           Atlantic City, New Jersey
# 3  08/06/1913    NaN  Victoria, British Columbia, Canada
# 4  09/09/1913  18:30                  Over the North Sea
#
#                           OPERATOR FLIGHT#          ROUTE  \
# 0  Military - U.S. Army Air Forces     NaN  Demonstration
# 1                          Unknown     NaN       Air show
# 2             Military - U.S. Navy     NaN    Test flight
# 3                          Private     NaN            NaN
# 4           Military - German Navy     NaN            NaN
#
#             AIRCRAFT_TYPE AIRCRAFT_REG CN_LN  TOTAL_ONBOARD  \
# 0        Wright Flyer III          NaN     1            2.0
# 1          Wright Byplane          SC1   NaN            1.0
# 2               Dirigible          NaN   NaN            5.0
# ...

# %%
org_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4975 entries, 0 to 4974
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DATE                  4975 non-null   object
#  1   TIME                  3459 non-null   object
#  2   LOCATION              4972 non-null   object
#  3   OPERATOR              4975 non-null   object
#  4   FLIGHT#               1318 non-null   object
#  5   ROUTE                 4197 non-null   object
#  6   AIRCRAFT_TYPE         4960 non-null   object
#  7   AIRCRAFT_REG          4701 non-null   object
#  8   CN_LN                 4302 non-null   object
#  9   TOTAL_ONBOARD         4957 non-null   float64
#  10  PASSENGER_ONBOARD     4746 non-null   float64
#  11  CREW_ONBOARD          4749 non-null   float64
#  12  TOTAL_FATALITIES      4967 non-null   float64
#  13  PASSENGER_FATALITIES  4732 non-null   float64
# ...

# %%
org_data.fillna(method='ffill', inplace=True)

# %%
org_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4975 entries, 0 to 4974
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DATE                  4975 non-null   object
#  1   TIME                  4975 non-null   object
#  2   LOCATION              4975 non-null   object
#  3   OPERATOR              4975 non-null   object
#  4   FLIGHT#               4834 non-null   object
#  5   ROUTE                 4975 non-null   object
#  6   AIRCRAFT_TYPE         4975 non-null   object
#  7   AIRCRAFT_REG          4974 non-null   object
#  8   CN_LN                 4975 non-null   object
#  9   TOTAL_ONBOARD         4975 non-null   float64
#  10  PASSENGER_ONBOARD     4975 non-null   float64
#  11  CREW_ONBOARD          4975 non-null   float64
#  12  TOTAL_FATALITIES      4975 non-null   float64
#  13  PASSENGER_FATALITIES  4975 non-null   float64
# ...

# %%
(org_data['FLIGHT#'].isnull()).value_counts()
org_data.dropna(inplace=True)

# %%
org_data['LOCATION'].unique()
# Out:
# array(['Solis, Uruguay', "L'Hospitalet, Ariège", 'Tarragona, Spain', ...,
#        'Almaty, Kazakhstan', 'Geneina, Sudan', 'Near Shahriah, Iran'],
#       dtype=object)

# %%
org_data.head()
# Out:
#            DATE   TIME              LOCATION              OPERATOR FLIGHT#  \
# 141  01/16/1928  10:00        Solis, Uruguay           Aeropostale  F-AIKG
# 142  01/22/1928  10:00  L'Hospitalet, Ariège           Aeropostale  F-AIKG
# 143  01/22/1928  10:00      Tarragona, Spain           Aeropostale  F-AIKG
# 144  01/27/1928  10:00        Almeria, Spain           Aeropostale  F-AIKG
# 145  02/26/1928  10:00   Marquette, Nebraska  Boeing Air Transport  F-AIKG
#
#                                                  ROUTE AIRCRAFT_TYPE  \
# 141                          Buenos Aires - Montevideo  Latecoere 25
# 142  Toulouse - Perpignan - Alicante - Casablanca -...    Breguet 14
# 143       Casablanca - Alicante - Perpignan - Toulouse    Breguet 14
# 144       Casablanca - Alicante - Perpignan - Toulouse    Breguet 14
# 145       Casablanca - Alicante - Perpignan - Toulouse     Boeing 40
#
#     AIRCRAFT_REG CN_LN  TOTAL_ONBOARD  PASSENGER_ONBOARD  CREW_ONBOARD  \
# ...

# %%
org_data.sort_values(by='PASSENGER_FATALITIES', ascending=False)
# Out:
#             DATE   TIME                                   LOCATION  \
# 2884  03/27/1977  17:07                   Tenerife, Canary Islands
# 3324  08/12/1985  18:56      Mt. Osutaka, near Ueno Village, Japan
# 2720  03/03/1974  11:41                  Near Ermenonville, France
# 4039  11/12/1996  18:40                  Near Charkhi Dadri, India
# 3320  06/23/1985  07:15  Atlantic Ocean, 110 miles West of Ireland
# ...          ...    ...                                        ...
# 3408  03/21/1987  13:55             Mount San Gorgonio, California
# 3407  03/13/1987  19:10                        Spokane, Washington
# 607   06/18/1941  17:00                         Bucharest, Romania
# 3383  10/04/1986  04:10                         San Antonio, Texas
# 141   01/16/1928  10:00                             Solis, Uruguay
#
#                                           OPERATOR    FLIGHT#  \
# 2884              Pan American World Airways / KLM  1736/4805
# ...

# %%
max_death = org_data.groupby(['DATE','PASSENGER_FATALITIES'], sort=False, as_index=False).size()

# %%
max_death.loc[max_death['DATE'] == '03/27/1977']

max_death.agg({'DATE': np.max, 'PASSENGER_FATALITIES': 'min'})
# Out:
# DATE                    12/31/2017
# PASSENGER_FATALITIES             0
# dtype: object

# %%
max_death[-10:].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
max_death['DATE'] = [x.split('/')[2] for x in max_death['DATE']
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
max2D = pca.fit_transform(max_death)
